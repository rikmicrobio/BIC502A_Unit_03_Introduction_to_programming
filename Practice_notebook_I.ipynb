# %% [markdown]
# # Python Programming Basics — Practice Problems
#
# **Bioinformatics for Beginners | Google Colab Worksheet**
#
# This worksheet is designed to practice the Python concepts covered in class:
#
# - Variables and values
# - Data types
# - Type conversion
# - `print()` and `input()`
# - Strings and biological sequences
# - Indexing and negative indexing
# - Slicing
# - Lists, tuples, sets and dictionaries
# - Arrays and nested lists
#
# ### How to use this notebook
#
# 1. Read each problem carefully.
# 2. Write your answer in the code cell below the question.
# 3. Run the cell using **Shift + Enter**.
# 4. Do not worry about making mistakes — try, run, read the error, and try again.
# 5. Use only the Python concepts taught in class.
#
# **Important:** Try to solve each problem yourself before asking for help.

# %% [markdown]
# ## Part A — Variables and Data Types
#
# ### Question 1 — Store a gene name
#
# Create a variable called `gene` and store the value `"TP53"` in it.
#
# Then print the variable.

# %%
# Your answer

# %% [markdown]
# ### Question 2 — Store biological information
#
# Create three variables:
#
# - `gene` = `"INS"`
# - `length` = `110`
# - `temperature` = `37.5`
#
# Print all three values.

# %%
# Your answer

# %% [markdown]
# ### Question 3 — Identify the data type
#
# Create these four variables:
#
# ```python
# gene = "BRCA1"
# length = 1863
# gc_content = 42.7
# is_coding = True
# ```
#
# Use `type()` to find the data type of each variable.

# %%
# Your answer

# %% [markdown]
# ### Question 4 — Simple calculation
#
# A DNA sequence contains 120 nucleotides.
#
# Create a variable called `sequence_length` and calculate the number of nucleotides after adding 30 more nucleotides.
#
# Print the result.

# %%
# Your answer

# %% [markdown]
# ## Part B — Type Conversion and Input
#
# ### Question 5 — Convert text into a number
#
# The value below is stored as text:
#
# ```python
# sample_count = "25"
# ```
#
# Convert it into an integer and multiply it by 2.
#
# What is the result?

# %%
# Your answer

# %% [markdown]
# ### Question 6 — Ask the user for a gene name
#
# Use `input()` to ask the user:
#
# > Enter the name of a gene:
#
# Store the answer in a variable called `gene` and print:
#
# > The gene is: ...

# %%
# Your answer

# %% [markdown]
# ### Question 7 — Ask for sequence length
#
# Ask the user to enter the length of a DNA sequence.
#
# Remember: `input()` gives you a string.
#
# Convert the answer to an integer and print the length.

# %%
# Your answer

# %% [markdown]
# ## Part C — Strings and Biological Sequences
#
# ### Question 8 — DNA length
#
# Create:
#
# ```python
# dna = "ATGCGTACGCTA"
# ```
#
# Use `len()` to find the length of the DNA sequence.

# %%
# Your answer

# %% [markdown]
# ### Question 9 — Count nucleotides
#
# Using:
#
# ```python
# dna = "ATGCGTACGCTA"
# ```
#
# Find:
#
# 1. Number of `A`
# 2. Number of `T`
# 3. Number of `G`
# 4. Number of `C`
#
# Use `.count()`.

# %%
# Your answer

# %% [markdown]
# ### Question 10 — Change sequence case
#
# Create:
#
# ```python
# sequence = "atgcctag"
# ```
#
# Print the sequence in:
#
# 1. Uppercase
# 2. Lowercase

# %%
# Your answer

# %% [markdown]
# ### Question 11 — Replace a nucleotide
#
# Create:
#
# ```python
# dna = "ATGCGT"
# ```
#
# Replace every `T` with `U`.
#
# Print the result.
#
# **Think:** What biological molecule does the new sequence resemble?

# %%
# Your answer

# %% [markdown]
# ## Part D — Indexing
#
# ### Question 12 — Find individual nucleotides
#
# Given:
#
# ```python
# dna = "ATGCGTAC"
# ```
#
# Print:
#
# 1. The first nucleotide
# 2. The second nucleotide
# 3. The fifth nucleotide
#
# Remember that Python starts counting from **0**.

# %%
# Your answer

# %% [markdown]
# ### Question 13 — Negative indexing
#
# Using:
#
# ```python
# dna = "ATGCGTAC"
# ```
#
# Print:
#
# 1. The last nucleotide
# 2. The second-last nucleotide
# 3. The third-last nucleotide
#
# Use negative indexing.

# %%
# Your answer

# %% [markdown]
# ## Part E — Slicing
#
# ### Question 14 — Extract a sequence region
#
# Given:
#
# ```python
# dna = "ATGCGTACGCTA"
# ```
#
# Extract and print the first 5 nucleotides.

# %%
# Your answer

# %% [markdown]
# ### Question 15 — Extract the middle region
#
# Using:
#
# ```python
# dna = "ATGCGTACGCTA"
# ```
#
# Extract nucleotides from index `3` to index `7`.
#
# **Remember:** the stop position is not included.

# %%
# Your answer

# %% [markdown]
# ### Question 16 — Last four nucleotides
#
# Using:
#
# ```python
# dna = "ATGCGTACGCTA"
# ```
#
# Extract the last four nucleotides.
#
# Try to solve this using slicing rather than counting the positions manually.

# %%
# Your answer

# %% [markdown]
# ### Question 17 — Extract every second nucleotide
#
# Given:
#
# ```python
# dna = "ATGCGTACGCTA"
# ```
#
# Use slicing with a step to print every second nucleotide.

# %%
# Your answer

# %% [markdown]
# ## Part F — Lists
#
# ### Question 18 — List of genes
#
# Create a list containing:
#
# ```text
# TP53, BRCA1, EGFR, KRAS
# ```
#
# Print the list.
#
# Then print the first gene in the list.

# %%
# Your answer

# %% [markdown]
# ### Question 19 — Add a gene
#
# Start with:
#
# ```python
# genes = ["TP53", "BRCA1", "EGFR"]
# ```
#
# Add `"KRAS"` to the end of the list using `append()`.
#
# Print the updated list.

# %%
# Your answer

# %% [markdown]
# ### Question 20 — Change a list item
#
# Start with:
#
# ```python
# genes = ["TP53", "BRCA1", "EGFR"]
# ```
#
# Change `"BRCA1"` to `"BRCA2"`.
#
# Print the updated list.

# %%
# Your answer

# %% [markdown]
# ### Question 21 — Remove an item
#
# Start with:
#
# ```python
# genes = ["TP53", "BRCA1", "EGFR", "KRAS"]
# ```
#
# Remove `"EGFR"` from the list.
#
# Print the list and its length.

# %%
# Your answer

# %% [markdown]
# ## Part G — Tuples and Sets
#
# ### Question 22 — Protein coordinates
#
# Create a tuple:
#
# ```text
# (10, 25, 40)
# ```
#
# Store it in a variable called `coordinates`.
#
# Print the tuple and print its second value.

# %%
# Your answer

# %% [markdown]
# ### Question 23 — Find unique nucleotides
#
# Create:
#
# ```python
# dna = "AATGCGTTAACCGG"
# ```
#
# Convert the DNA sequence into a set.
#
# What unique nucleotide symbols are present?

# %%
# Your answer

# %% [markdown]
# ### Question 24 — Remove duplicate gene names
#
# Create:
#
# ```python
# genes = ["TP53", "BRCA1", "TP53", "EGFR", "BRCA1", "KRAS"]
# ```
#
# Convert the list into a set to identify the unique genes.

# %%
# Your answer

# %% [markdown]
# ## Part H — Dictionaries
#
# ### Question 25 — Gene information
#
# Create a dictionary containing:
#
# ```text
# gene       = TP53
# organism   = Human
# length     = 393
# ```
#
# Use suitable keys such as `"gene"`, `"organism"` and `"length"`.
#
# Then print the gene name and gene length separately.

# %%
# Your answer

# %% [markdown]
# ### Question 26 — Add information to a dictionary
#
# Start with:
#
# ```python
# protein = {
#     "name": "Insulin",
#     "organism": "Human"
# }
# ```
#
# Add a new key called `"length"` with the value `110`.
#
# Print the complete dictionary.

# %%
# Your answer

# %% [markdown]
# ## Part I — Nested Lists and Simple Arrays
#
# ### Question 27 — Expression values
#
# Create this nested list:
#
# ```python
# expression = [
#     [10, 20, 30],
#     [15, 25, 35],
#     [12, 22, 32]
# ]
# ```
#
# Print:
#
# 1. The first row
# 2. The second value of the first row
# 3. The third value of the third row

# %%
# Your answer

# %% [markdown]
# ### Question 28 — A small gene expression matrix
#
# Use:
#
# ```python
# expression = [
#     [10, 20, 30],
#     [5, 15, 25]
# ]
# ```
#
# Think of:
#
# - Rows = genes
# - Columns = samples
#
# Find the value for **Gene 2, Sample 3** using two-level indexing.

# %%
# Your answer

# %% [markdown]
# ### Question 29 — Simple numerical array
#
# Create a list containing these expression values:
#
# ```text
# 12, 18, 25, 20, 15
# ```
#
# Find:
#
# 1. The first value
# 2. The last value
# 3. The number of values
# 4. The sum of the values

# %%
# Your answer

# %% [markdown]
# ## Part J — Mini Bioinformatics Challenges
#
# ### Question 30 — DNA summary
#
# Create:
#
# ```python
# dna = "ATGCGCGTATGC"
# ```
#
# Write a small program that prints:
#
# - DNA sequence
# - Sequence length
# - Number of A
# - Number of T
# - Number of G
# - Number of C

# %%
# Your answer

# %% [markdown]
# ### Question 31 — Sequence region investigator
#
# Given:
#
# ```python
# protein = "MKWVTFISLLFLFSSAYS"
# ```
#
# Write code to print:
#
# 1. First amino acid
# 2. Last amino acid
# 3. First five amino acids
# 4. Last five amino acids
# 5. Length of the protein sequence

# %%
# Your answer

# %% [markdown]
# ### Question 32 — Gene information card
#
# Create a dictionary for a fictional gene containing:
#
# - Gene name
# - Organism
# - Sequence length
# - Function
#
# Then print a short information card using the values from the dictionary.
#
# Example format:
#
# ```text
# Gene: ...
# Organism: ...
# Length: ...
# Function: ...
# ```

# %%
# Your answer

# %% [markdown]
# # Bonus Challenge — Build Your Own Sequence Analyzer
#
# Create a program that asks the user to enter a DNA sequence.
#
# The program should report:
#
# 1. The sequence
# 2. Its length
# 3. Number of A
# 4. Number of T
# 5. Number of G
# 6. Number of C
# 7. First nucleotide
# 8. Last nucleotide
# 9. First three nucleotides
# 10. Last three nucleotides
#
# ### Challenge rule
#
# Try to use only the concepts learned in this class.

# %%
# Your answer

# %% [markdown]
# # Self-Check
#
# Before finishing, ask yourself:
#
# - Can I create and use a variable?
# - Can I identify `int`, `float`, `str` and `bool`?
# - Can I convert a string to an integer?
# - Can I use `input()` and `print()`?
# - Can I calculate the length of a sequence?
# - Can I count nucleotides?
# - Do I understand zero-based indexing?
# - Can I use negative indexing?
# - Can I slice a sequence?
# - Do I know when to use a list, tuple, set or dictionary?
# - Can I access an item in a nested list?
#
# **Goal:** Understand the logic first. Speed comes later.
